# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
# %matplotlib inline

# %%
df = pd.read_csv('cleaned_data.csv')
df.head()
# Out:
#    Unnamed: 0              name  year                           revenue  \
# 0           0     Skillquotient  2016         $25 to $100 million (USD)
# 1           1       Sephora USA  1969            $1 to $5 billion (USD)
# 2           2           REVOLVE  2003  $500 million to $1 billion (USD)
# 3           3  Costco Wholesale  1976          Unknown / Non-Applicable
# 4           4          Anblicks  2004           $5 to $25 million (USD)
#
#                  employee                  sector  \
# 0   501 to 1000 Employees  Information Technology
# 1        10000+ Employees      Retail & Wholesale
# 2  1001 to 5000 Employees      Retail & Wholesale
# 3        10000+ Employees      Retail & Wholesale
# 4    201 to 500 Employees  Information Technology
#
#                                   job_title location      salary_est  age  \
# 0     Artificial Intelligence- Data Science   Remote   $76k - $179k     7
# 1           Manager, Data Science Analytics   Remote  $180k - $181k    54
# ...

# %%
def dist(df, col):
    import warnings
    warnings.simplefilter("ignore", UserWarning)
    
    fig = plt.figure(figsize=(8, 4))
    fig.suptitle(col.upper(), fontsize=10, color='b')
    
    plt.subplot(1,2,1)
    sns.distplot(df[col], color='red')

    plt.subplot(1,2,2)
    sns.boxplot(y=df[col])

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'year', 'revenue', 'employee', 'sector',
#        'job_title', 'location', 'salary_est', 'age', 'min_salary',
#        'max_salary', 'avg_salary'],
#       dtype='object')

# %%
col = ['avg_salary', 'age']

# %%
for img in col:
    dist(df, img)

# %%
sns.countplot(x=df.location)
plt.xticks(rotation=90)
plt.show()

# %%
df.pivot_table(index='location', values='avg_salary', aggfunc='mean').sort_values('avg_salary', ascending=False)
# Out:
#           avg_salary
# location
#  WI       255.000000
#  AZ       204.000000
#  IA       202.750000
#  OR       185.500000
#  PA       173.142857
#  NJ       140.625000
#  TX       137.462500
#  GA       137.062500
#  IL       137.058824
#  CT       130.625000
#  MA       129.583333
#  CA       129.113772
#  NY       126.302083
#  WA       123.000000
#  ND       121.000000
# Remote    119.844118
#  FL       118.250000
#  DC       117.750000
#  OH       115.083333
#  MD       110.700000
#  NC       107.055556
#  ME       104.833333
#  KY       103.500000
#  MN        94.250000

# %%
df.pivot_table(index='revenue', values='avg_salary', aggfunc='mean').sort_values('avg_salary', ascending=False)
# Out:
#                                   avg_salary
# revenue
# Less than $1 million (USD)        207.090909
# $100 to $500 million (USD)        189.800000
# Unknown / Non-Applicable          135.806548
# $10+ billion (USD)                133.695531
# $500 million to $1 billion (USD)  131.700000
# $1 to $5 billion (USD)            116.888298
# $25 to $100 million (USD)          99.305556
# $5 to $25 million (USD)            87.754902
# $5 to $10 billion (USD)            87.461538
